# %% [markdown]
# #### Continent-content collision:
# ##### Model parameters
# * Model duration: µ = 50 Ma
# * Horizons to track: 10
# * Horizon depths: [5, 8, 11, 13, 15, 17, 19, 21, 23, 25]
#
# ##### Lithology and heat :
# * Basement thermal conductivity: µ = 2.5
# * Surface heat production: µ = 2
# * Heat production depth: µ = 45 Km
# * Surface heat flow: µ = 100 > (hp_dep * surf_hp)
# * Number of heat flow variations (INT): 0
# * Time of heat flow at change: Na
# * Value of heat flow at change: Na
# * Temperature at upper surface boundary (ºC):
#
# ##### Exhumation history
# * Uplift rate: uniform distribution of erosion rates between 0 and 5 mm/yr
# * Num uplift/erosion periods (INT): µ = 3
# * Beginning of uplift period:
# * Duration of uplift period:
# * Total uplift during episode

# %%
import SampleGenerator

n=50
chunk_size=10
orogen="CC"
output_dir="out"
tmp_dir = "tmp"

results = SampleGenerator.generate_models(n, chunk_size, orogen, output_dir, tmp_dir)

# %%
for c, s in results:
    ages, ahe, aft, zhe, zft = c
    plt.figure(i)
    plt.title(s.exhumation_rates)
    plt.plot(ages, aft)
    plt.plot(ages, ahe)
    plt.plot(ages, zhe)
    plt.plot(ages, zft)
    #print(c)
    #s.summary()
    i+=1
# Out:
# <ipython-input-185-9c06625af1ab>:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(i)
